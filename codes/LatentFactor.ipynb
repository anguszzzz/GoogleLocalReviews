# %%
import gzip
from collections import defaultdict,Counter
from random import shuffle
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
allReviews = []
with open('../CA_reviews.txt',encoding='utf-8') as f:
    for l in f:
        allReviews.append(eval(l))
            
middleSet,testSet = train_test_split(allReviews,test_size=0.2)
trainSet,validSet = train_test_split(middleSet,test_size=0.125)

# %%
# def predict(dataset, alpha, beta_u, beta_i):
def calMSE(dataset, alpha, beta_u, beta_p):
    avg_beta_u = sum(beta_u[k] for k in beta_u)/len(beta_u)
    avg_beta_p = sum(beta_p[k] for k in beta_p)/len(beta_p)
    
    MSE = 0
    for l in dataset:
        user,place,rating = l['gPlusUserId'],l['gPlusPlaceId'],l['rating']
        
        predRating = alpha \
            + (beta_u[user] if user in beta_u else avg_beta_u) \
            + (beta_p[place] if place in beta_p else avg_beta_p)
        MSE += (predRating - rating) ** 2
    MSE /= len(dataset)
    return MSE

# %%
allRatings = defaultdict(int)
user_places = defaultdict(set)
place_users = defaultdict(set)
for l in trainSet:
    user, place, rating = l['gPlusUserId'], l['gPlusPlaceId'], l['rating']
    user_places[user].add(place)
    place_users[place].add(user)
    allRatings[user + place] = rating

# %%
### Using Latent factor model with only alpha and beta
    
def gridSearch(lams):
    lam1, lam2 = lams
    prev_alpha = 0
    prev_beta_u = defaultdict(int)
    prev_beta_p = defaultdict(int)
    prev_MSE = 0
#     iterCount = 0

    while (True):
        alpha = 0
        beta_u = defaultdict(int)
        beta_p = defaultdict(int)
        for l in trainSet:
            user, place, rating = l['gPlusUserId'], l['gPlusPlaceId'], l['rating']
            alpha += rating - (prev_beta_u[user] + prev_beta_p[place])
        alpha /= len(allRatings)

        for user in user_places:
            for place in user_places[user]:
                beta_u[user] += allRatings[user + place] - (alpha + prev_beta_p[place])
            beta_u[user] /= (lam1 + len(user_places[user]))

        for place in place_users:
            for user in place_users[place]:
                beta_p[place] += allRatings[user + place] - (alpha + prev_beta_u[user])
            beta_p[place] /= (lam2 + len(place_users[place]))

        MSE = calMSE(trainSet, alpha, beta_u, beta_p)

        if abs(prev_MSE - MSE) < 0.0001:
            print('lambda is:', lams)
            print("Alpha is " , alpha)
            print("Training Mean Square Error is ", MSE)
            validMSE = calMSE(validSet, alpha, beta_u, beta_p)
            print("Validation Mean Square Error is ", validMSE)
            return (validMSE, alpha, beta_u, beta_p)
        prev_MSE = MSE
        prev_alpha = alpha
        prev_beta_u = beta_u
        prev_beta_p = beta_p

# %%
lams = ((l1 / 10.0,l2 / 10.0) for l1 in range(25,35) for l2 in range(25,35))
lamPair = min(lams, key=gridSearch)
curr_mse, alpha, beta_u, beta_i = gridSearch(lamPair)
print("Best lambda is: ",lamPair)
print("Using this lambda, the mean square error on the validation set is: " ,curr_mse)
# Out:
# lambda is: (2.5, 2.5)
# Alpha is  4.056718095557591
# Training Mean Square Error is  0.5437329375610713
# Validation Mean Square Error is  1.1765108644846956
# lambda is: (2.5, 2.6)
# Alpha is  4.056994169922862
# Training Mean Square Error is  0.5469367398420749
# Validation Mean Square Error is  1.1764860522620812
# lambda is: (2.5, 2.7)
# Alpha is  4.057276633374055
# Training Mean Square Error is  0.5500411010718068
# Validation Mean Square Error is  1.1765275311078591
# lambda is: (2.5, 2.8)
# Alpha is  4.057563910817
# Training Mean Square Error is  0.5530509762947973
# Validation Mean Square Error is  1.1766274156845162
# lambda is: (2.5, 2.9)
# Alpha is  4.057854685252135
# Training Mean Square Error is  0.5559709979568128
# Validation Mean Square Error is  1.1767788313094778
# lambda is: (2.5, 3.0)
# Alpha is  4.058147853715208
# Training Mean Square Error is  0.5588054991263867
# Validation Mean Square Error is  1.1769757644853795
# lambda is: (2.5, 3.1)
# Alpha is  4.058442491429695
# Training Mean Square Error is  0.5615585354060783
# Validation Mean Square Error is  1.1772129387421122
# lambda is: (2.5, 3.2)
# Alpha is  4.058737822458741
# Training Mean Square Error is  0.5642339054349457
# Validation Mean Square Error is  1.1774857109632464
# lambda is: (2.5, 3.3)
# Alpha is  4.05903319561317
# Training Mean Square Error is  0.5668351699582853
# Validation Mean Square Error is  1.1777899843916604
# lambda is: (2.5, 3.4)
# Alpha is  4.059328064554135
# Training Mean Square Error is  0.5693656694895732
# Validation Mean Square Error is  1.178122135291181
# lambda is: (2.6, 2.5)
# Alpha is  4.056443904759463
# Training Mean Square Error is  0.5509232313879812
# Validation Mean Square Error is  1.1762987906183082
# lambda is: (2.6, 2.6)
# Alpha is  4.056718802316158
# Training Mean Square Error is  0.5541663262972256
# Validation Mean Square Error is  1.176257811432887
# lambda is: (2.6, 2.7)
# Alpha is  4.057000127435011
# Training Mean Square Error is  0.5573091375600963
# Validation Mean Square Error is  1.1762839534947767
# lambda is: (2.6, 2.8)
# Alpha is  4.057286301901605
# Training Mean Square Error is  0.5603566412136693
# Validation Mean Square Error is  1.1763692794698484
# lambda is: (2.6, 2.9)
# Alpha is  4.057576006099295
# Training Mean Square Error is  0.5633134912975419
# Validation Mean Square Error is  1.1765068663838494
# lambda is: (2.6, 3.0)
# Alpha is  4.057868134860853
# Training Mean Square Error is  0.5661840427514881
# Validation Mean Square Error is  1.176690655919264
# lambda is: (2.6, 3.1)
# Alpha is  4.058161761524008
# Training Mean Square Error is  0.5689723730811396
# Validation Mean Square Error is  1.1769153300191224
# lambda is: (2.6, 3.2)
# Alpha is  4.0590957466346955
# Training Mean Square Error is  0.5717534018944498
# Validation Mean Square Error is  1.1772257526120284
# lambda is: (2.6, 3.3)
# Alpha is  4.059361000401783
# Training Mean Square Error is  0.5743863740235425
# Validation Mean Square Error is  1.1775177168920392
# lambda is: (2.6, 3.4)
# Alpha is  4.059627508969315
# Training Mean Square Error is  0.5769480051171831
# Validation Mean Square Error is  1.1778381166616363
# lambda is: (2.7, 2.5)
# Alpha is  4.056182473495512
# Training Mean Square Error is  0.5578155542335398
# Validation Mean Square Error is  1.1761386535782028
# lambda is: (2.7, 2.6)
# Alpha is  4.056456243537719
# Training Mean Square Error is  0.5610964069714472
# Validation Mean Square Error is  1.176082478858768
# lambda is: (2.7, 2.7)
# Alpha is  4.0567364763057014
# Training Mean Square Error is  0.5642761701662062
# Validation Mean Square Error is  1.1760942015276583
# lambda is: (2.7, 2.8)
# Alpha is  4.057021590816052
# Training Mean Square Error is  0.5673598396562883
# Validation Mean Square Error is  1.176165836028016
# lambda is: (2.7, 2.9)
# Alpha is  4.058042341810881
# Training Mean Square Error is  0.5704237930171107
# Validation Mean Square Error is  1.176338910078001
# lambda is: (2.7, 3.0)
# Alpha is  4.0582983677388285
# Training Mean Square Error is  0.5733266637836537
# Validation Mean Square Error is  1.1765093559038995
# lambda is: (2.7, 3.1)
# Alpha is  4.058558110644653
# Training Mean Square Error is  0.5761467269852422
# Validation Mean Square Error is  1.1767213085300205
# lambda is: (2.7, 3.2)
# Alpha is  4.05882062572414
# Training Mean Square Error is  0.5788878118138783
# Validation Mean Square Error is  1.1769700512834627
# lambda is: (2.7, 3.3)
# Alpha is  4.059085107151676
# Training Mean Square Error is  0.5815535103408548
# Validation Mean Square Error is  1.1772514188508005
# lambda is: (2.7, 3.4)
# Alpha is  4.05935086698741
# Training Mean Square Error is  0.58414719479462
# Validation Mean Square Error is  1.1775617236011149
# lambda is: (2.8, 2.5)
# Alpha is  4.055932752832679
# Training Mean Square Error is  0.5644281023571995
# Validation Mean Square Error is  1.1760239631262648
# lambda is: (2.8, 2.6)
# Alpha is  4.057050835907701
# Training Mean Square Error is  0.5678184861089602
# Validation Mean Square Error is  1.1760011877087047
# lambda is: (2.8, 2.7)
# Alpha is  4.057287315545089
# Training Mean Square Error is  0.5710311797902725
# Validation Mean Square Error is  1.1759983662911062
# lambda is: (2.8, 2.8)
# Alpha is  4.057531497272808
# Training Mean Square Error is  0.5741471955638991
# Validation Mean Square Error is  1.176056153687679
# lambda is: (2.8, 2.9)
# Alpha is  4.057781841597042
# Training Mean Square Error is  0.577171211302092
# Validation Mean Square Error is  1.1761675424357272
# lambda is: (2.8, 3.0)
# Alpha is  4.058037041641064
# Training Mean Square Error is  0.5801076083435945
# Validation Mean Square Error is  1.1763263952654137
# lambda is: (2.8, 3.1)
# Alpha is  4.0582959859031424
# Training Mean Square Error is  0.5829604923969299
# Validation Mean Square Error is  1.1765273204267614
# lambda is: (2.8, 3.2)
# Alpha is  4.058557727555048
# Training Mean Square Error is  0.5857337132598482
# Validation Mean Square Error is  1.176765567479119
# lambda is: (2.8, 3.3)
# Alpha is  4.058821459020679
# Training Mean Square Error is  0.5884308832789102
# Validation Mean Square Error is  1.1770369397582416
# lambda is: (2.8, 3.4)
# Alpha is  4.059086490842603
# Training Mean Square Error is  0.5910553945408873
# Validation Mean Square Error is  1.1773377205135636
# lambda is: (2.9, 2.5)
# Alpha is  4.056578067789483
# Training Mean Square Error is  0.5708477762766312
# Validation Mean Square Error is  1.1759943641789026
# lambda is: (2.9, 2.6)
# Alpha is  4.0568041030786635
# Training Mean Square Error is  0.5741972984651867
# Validation Mean Square Error is  1.1759094702091433
# lambda is: (2.9, 2.7)
# Alpha is  4.057039694155022
# Training Mean Square Error is  0.5774443924264288
# Validation Mean Square Error is  1.1758938963918228
# lambda is: (2.9, 2.8)
# Alpha is  4.057283020074768
# Training Mean Square Error is  0.5805940735953083
# Validation Mean Square Error is  1.1759395728495559
# lambda is: (2.9, 2.9)
# Alpha is  4.057532538419065
# Training Mean Square Error is  0.5836510394069802
# Validation Mean Square Error is  1.176039452781066
# lambda is: (2.9, 3.0)
# Alpha is  4.057786939827432
# Training Mean Square Error is  0.586619690953127
# Validation Mean Square Error is  1.1761873623574055
# lambda is: (2.9, 3.1)
# Alpha is  4.058045110669476
# Training Mean Square Error is  0.5895041536781435
# Validation Mean Square Error is  1.1763778758658578
# lambda is: (2.9, 3.2)
# Alpha is  4.058306102289623
# Training Mean Square Error is  0.5923082969408909
# Validation Mean Square Error is  1.176606211316488
# lambda is: (2.9, 3.3)
# Alpha is  4.058569105531556
# Training Mean Square Error is  0.5950357523580706
# Validation Mean Square Error is  1.1768681427327403
# lambda is: (2.9, 3.4)
# Alpha is  4.058833429562345
# Training Mean Square Error is  0.5976899309080476
# Validation Mean Square Error is  1.177159926119578
# lambda is: (3.0, 2.5)
# Alpha is  4.05634248443127
# Training Mean Square Error is  0.576944644415171
# Validation Mean Square Error is  1.1759514692129884
# lambda is: (3.0, 2.6)
# Alpha is  4.056567630667033
# Training Mean Square Error is  0.5803279977083052
# Validation Mean Square Error is  1.1758538865384667
# lambda is: (3.0, 2.7)
# Alpha is  4.056802366036119
# Training Mean Square Error is  0.583608200659411
# Validation Mean Square Error is  1.175826266676256
# lambda is: (3.0, 2.8)
# Alpha is  4.05704486645467
# Training Mean Square Error is  0.5867902867292695
# Validation Mean Square Error is  1.1758605003046434
# lambda is: (3.0, 2.9)
# Alpha is  4.057293586861191
# Training Mean Square Error is  0.5898789718632466
# Validation Mean Square Error is  1.1759495038931227
# lambda is: (3.0, 3.0)
# Alpha is  4.05754721563827
# Training Mean Square Error is  0.5928786758801724
# Validation Mean Square Error is  1.1760870694448466
# lambda is: (3.0, 3.1)
# Alpha is  4.057804637234239
# Training Mean Square Error is  0.5957935429644358
# Validation Mean Square Error is  1.1762677394775496
# lambda is: (3.0, 3.2)
# Alpha is  4.058064901337275
# Training Mean Square Error is  0.5986274610732525
# Validation Mean Square Error is  1.1764867024666579
# lambda is: (3.0, 3.3)
# Alpha is  4.058327197363898
# Training Mean Square Error is  0.6013840801638851
# Validation Mean Square Error is  1.1767397049752844
# lambda is: (3.0, 3.4)
# Alpha is  4.058590833241594
# Training Mean Square Error is  0.6040668292119049
# Validation Mean Square Error is  1.177022977469475
# lambda is: (3.1, 2.5)
# Alpha is  4.0561163755591565
# Training Mean Square Error is  0.5828089687989961
# Validation Mean Square Error is  1.1759397077337574
# lambda is: (3.1, 2.6)
# Alpha is  4.0563406663107875
# Training Mean Square Error is  0.5862249028511973
# Validation Mean Square Error is  1.1758301257108408
# lambda is: (3.1, 2.7)
# Alpha is  4.056574576949338
# Training Mean Square Error is  0.5895369942619746
# Validation Mean Square Error is  1.175791111558046
# lambda is: (3.1, 2.8)
# Alpha is  4.056816280548723
# Training Mean Square Error is  0.5927502935357474
# Validation Mean Square Error is  1.1758145190929172
# lambda is: (3.1, 2.9)
# Alpha is  4.057064229637006
# Training Mean Square Error is  0.5958695341621193
# Validation Mean Square Error is  1.175893230424418
# lambda is: (3.1, 3.0)
# Alpha is  4.057317110557406
# Training Mean Square Error is  0.5988991537428646
# Validation Mean Square Error is  1.1760210055601727
# lambda is: (3.1, 3.1)
# Alpha is  4.05757380601664
# Training Mean Square Error is  0.6018433142831975
# Validation Mean Square Error is  1.176192357243597
# lambda is: (3.1, 3.2)
# Alpha is  4.057833364206352
# Training Mean Square Error is  0.6047059214488806
# Validation Mean Square Error is  1.1764024462492948
# lambda is: (3.1, 3.3)
# Alpha is  4.058094973249651
# Training Mean Square Error is  0.6074906426776417
# Validation Mean Square Error is  1.1766469933678327
# lambda is: (3.1, 3.4)
# Alpha is  4.0583579399554415
# Training Mean Square Error is  0.6102009241134985
# Validation Mean Square Error is  1.1769222050811972
# lambda is: (3.2, 2.5)
# Alpha is  4.055899067462211
# Training Mean Square Error is  0.5884539452996447
# Validation Mean Square Error is  1.1759553773453346
# lambda is: (3.2, 2.6)
# Alpha is  4.05612253428599
# Training Mean Square Error is  0.5919012776398617
# Validation Mean Square Error is  1.175834432917179
# lambda is: (3.2, 2.7)
# Alpha is  4.056355649402348
# Training Mean Square Error is  0.5952441029728505
# Validation Mean Square Error is  1.1757846269300811
# lambda is: (3.2, 2.8)
# Alpha is  4.05659658329808
# Training Mean Square Error is  0.5984874879466858
# Validation Mean Square Error is  1.1757977786899936
# lambda is: (3.2, 2.9)
# Alpha is  4.056843786317481
# Training Mean Square Error is  0.6016361827058461
# Validation Mean Square Error is  1.1758667381005157
# lambda is: (3.2, 3.0)
# Alpha is  4.057095942953917
# Training Mean Square Error is  0.604694641763692
# Validation Mean Square Error is  1.175985235153606
# lambda is: (3.2, 3.1)
# Alpha is  4.057351934330625
# Training Mean Square Error is  0.6076670440978088
# Validation Mean Square Error is  1.176147754637556
# lambda is: (3.2, 3.2)
# Alpha is  4.057610807288737
# Training Mean Square Error is  0.6105573122572396
# Validation Mean Square Error is  1.1763494312999065
# lambda is: (3.2, 3.3)
# Alpha is  4.057871748785568
# Training Mean Square Error is  0.6133691303627679
# Validation Mean Square Error is  1.1765859617006191
# lambda is: (3.2, 3.4)
# Alpha is  4.058134064609889
# Training Mean Square Error is  0.6161059609566146
# Validation Mean Square Error is  1.1768535297589675
# lambda is: (3.3, 2.5)
# Alpha is  4.05568995330268
# Training Mean Square Error is  0.5938918093337489
# Validation Mean Square Error is  1.175995244869306
# lambda is: (3.3, 2.6)
# Alpha is  4.055912625875989
# Training Mean Square Error is  0.5973694207824579
# Validation Mean Square Error is  1.1758635275926692
# lambda is: (3.3, 2.7)
# Alpha is  4.056144973008528
# Training Mean Square Error is  0.6007418870661474
# Validation Mean Square Error is  1.175803487627703
# lambda is: (3.3, 2.8)
# Alpha is  4.056385162834354
# Training Mean Square Error is  0.6040142901478537
# Validation Mean Square Error is  1.1758069119095702
# lambda is: (3.3, 2.9)
# Alpha is  4.056631643718522
# Training Mean Square Error is  0.6071913960078952
# Validation Mean Square Error is  1.1758666201034935
# lambda is: (3.3, 3.0)
# Alpha is  4.056883098472726
# Training Mean Square Error is  0.6102776752654674
# Validation Mean Square Error is  1.1759763139935324
# lambda is: (3.3, 3.1)
# Alpha is  4.057138406791883
# Training Mean Square Error is  0.6132773230837604
# Validation Mean Square Error is  1.1761304520764553
# lambda is: (3.3, 3.2)
# Alpha is  4.057396614289565
# Training Mean Square Error is  0.6161942781306912
# Validation Mean Square Error is  1.1763241446043977
# lambda is: (3.3, 3.3)
# Alpha is  4.057656906866314
# Training Mean Square Error is  0.6190322404682663
# Validation Mean Square Error is  1.1765530653180805
# lambda is: (3.3, 3.4)
# Alpha is  4.057918589401363
# Training Mean Square Error is  0.6217946883205655
# Validation Mean Square Error is  1.176813376876883
# lambda is: (3.4, 2.5)
# Alpha is  4.055488484885327
# Training Mean Square Error is  0.5991339176370957
# Validation Mean Square Error is  1.1760564786752126
# lambda is: (3.4, 2.6)
# Alpha is  4.05571039112208
# Training Mean Square Error is  0.6026407480604425
# Validation Mean Square Error is  1.1759145351778584
# lambda is: (3.4, 2.7)
# Alpha is  4.055941996239474
# Training Mean Square Error is  0.6060418197826066
# Validation Mean Square Error is  1.1758447786615527
# lambda is: (3.4, 2.8)
# Alpha is  4.056181466229757
# Training Mean Square Error is  0.6093422293181965
# Validation Mean Square Error is  1.1758389656466408
# lambda is: (3.4, 2.9)
# Alpha is  4.056427247657677
# Training Mean Square Error is  0.6125467577259548
# Validation Mean Square Error is  1.1758898873590018
# lambda is: (3.4, 3.0)
# Alpha is  4.056678021815503
# Training Mean Square Error is  0.6156598909848388
# Validation Mean Square Error is  1.1759912190305657
# lambda is: (3.4, 3.1)
# Alpha is  4.056932667099919
# Training Mean Square Error is  0.6186858397140084
# Validation Mean Square Error is  1.176137394390548
# lambda is: (3.4, 3.2)
# Alpha is  4.057190228016987
# Training Mean Square Error is  0.6216285579884149
# Validation Mean Square Error is  1.1763235006004091
# lambda is: (3.4, 3.3)
# Alpha is  4.0574498895118705
# Training Mean Square Error is  0.6244917611219221
# Validation Mean Square Error is  1.1765451898774972
# lambda is: (3.4, 3.4)
# Alpha is  4.057710955634429
# Training Mean Square Error is  0.6272789423520723
# Validation Mean Square Error is  1.1767986048174832
# lambda is: (3.2, 2.7)
# Alpha is  4.056355649402348
# Training Mean Square Error is  0.5952441029728505
# Validation Mean Square Error is  1.1757846269300811
# Best lambda is:  (3.2, 2.7)
# Using this lambda, the mean square error on the validation set is:  1.1757846269300811

# %%
testMSE = calMSE(testSet, alpha, beta_u, beta_i)
print("Test Mean Square Error is ", testMSE)
# Out:
# Test Mean Square Error is  1.1887627544667272
